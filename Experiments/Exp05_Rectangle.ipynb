# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Create a black image of size 500x500
img = np.zeros((500, 500, 3), dtype=np.uint8)

# Draw rectangle
cv2.rectangle(img, (100, 100), (400, 300), (0, 255, 0), 4)

# Convert BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display image
plt.imshow(img)
plt.axis('off')
plt.show()
